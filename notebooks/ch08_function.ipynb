# %% [markdown]
# # 8.1 定义函数

# %%
# greeter.py
def greet_user(name):
    print(f"Hello, {name.title()}! Welcome to the Python programming world.")

greet_user('Wu')
# Out:
# Hello, Wu! Welcome to the Python programming world.

# %%
# 8-1 message.py
def display_message():
    print("In this chapter, we will learn about functions in Python.")
display_message()
# Out:
# In this chapter, we will learn about functions in Python.

# %%
# 8-2 favorite_book.py
def favorite_book(title):
    print(f"One of my favorite books is '{title.title() } .'")
favorite_book('long walk to freedom')
# Out:
# One of my favorite books is 'Long Walk To Freedom .'

# %% [markdown]
# # 8.2 传递实参

# %%
def describe_pet(pet_name, animal_type='dog'):
    print(f"I have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet(pet_name='willie')
describe_pet('willie')
# Out:
# I have a dog.
# My dog's name is Willie.
# I have a dog.
# My dog's name is Willie.

# %%
# 8-3 t-shirt.py
def make_shirt(size, message):
    print(f"This shirt is {size} size and added '{message}' on it.")
make_shirt(26, 'good boy')
make_shirt(message='good boy', size=26)
# Out:
# This shirt is 26 size and added 'good boy' on it.
# This shirt is 26 size and added 'good boy' on it.

# %%
# 8-4 bigger t-shirt.py
def make_shirt(size='big', message='I Love Python'):
    print(f"This shirt is {size}, and has '{message}' on it.")
make_shirt()
make_shirt(size='medium')
make_shirt(message='I really Love Python')
# Out:
# This shirt is big, and has 'I Love Python' on it.
# This shirt is medium, and has 'I Love Python' on it.
# This shirt is big, and has 'I really Love Python' on it.

# %%
# 8-5 cities
def describe_city(city_name, city_nation='China'):
    print(f"{city_name} is in {city_nation}")
describe_city('Beijing')
describe_city('Shanghai')
describe_city('where')
# Out:
# Beijing is in China
# Shanghai is in China
# where is in China

# %%
import dis

def f(x):
    return x + 1

dis.dis(f)
# Out:
#   3           0 RESUME                   0
#
#   4           2 LOAD_FAST                0 (x)
#               4 LOAD_CONST               1 (1)
#               6 BINARY_OP                0 (+)
#              10 RETURN_VALUE

# %%
# formatted_name.py
def get_formatted_name(first_name, last_name):
    full_name = f"{first_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('jimi', 'hendrix')
print(musician)
# Out:
# Jimi Hendrix

# %%
# formatted_name.py
def get_formatted_name(first_name, last_name, middle_name=''):
    if  middle_name:
        full_name = f"{first_name} {middle_name} {last_name}"
    else:
        full_name = f"{first_name} {last_name}"
    return full_name.title()

musician = get_formatted_name('jimi', 'hendrix')
print(musician)
musician = get_formatted_name('jimi', 'hendrix', 'lee')
print(musician)
# Out:
# Jimi Hendrix
# Jimi Lee Hendrix

# %%
def build_person(first_name, last_name):
    person = {
        'first_name':first_name, 
        'last_name':last_name,
        'full_name':f"{first_name} {last_name}"
        }
    return person
user = build_person('wu', 'kaiyuan')
print(user)
# Out:
# {'first_name': 'wu', 'last_name': 'kaiyuan', 'full_name': 'wu kaiyuan'}

# %%
def greeting_formative(first_name, last_name, middle_name=''):
    if middle_name:
        full_name = f"{first_name} {middle_name} {last_name}"
    else:
        full_name = f"{first_name} {last_name}"
    return full_name.title()

while True:
    print("\nPlease input your name:")
    print("\nEnter 'q' at any time to quit")

    first_name = input("First name:")
    if first_name == 'q':
        break

    middle_name = input("Middle name(Skip if N/A):")
    if middle_name == 'q':
        break

    last_name = input("Last name:")
    if last_name == 'q':
        break
    
    formatted_name = greeting_formative(first_name, last_name, middle_name)
    print("\nHello, " + formatted_name + "!")
# Out:
# Please input your name:
#
# Enter 'q' at any time to quit
#
# Hello, Wu Kai Yuan!
#
# Please input your name:
#
# Enter 'q' at any time to quit

# %%
# 8-6 cities_names
def city_country(city_name, nation):
    output = f"{nation}, {city_name}"
    return output.title()

while True:
    city_name = input("City name:")
    if city_name == 'q':
        break

    nation = input("Nation:")
    if nation == 'q':
        break

    result = city_country(city_name, nation)
    print(result)
# Out:
# China, Beijing
# Uk, Lonton
# Usa, Newyorkcity

# %%
# 8-7+8 Album
albums = []
def make_album(singer, album_name, sing_num = ''):
    if sing_num:
        return {
            'singer':singer,
            'album_name': album_name,
            'sing_num': sing_num
        }
    else:
        return {
            'singer':singer,
            'album_name': album_name,
        }

print("\nEnter 'q' at any time to quit")
while True:
    print("\nPlease enter the singer:")
    singer = input('Singer name:')
    if singer == 'q':
        break

    print("\nPlease enter the album:")
    album_name = input('Album name:')
    if album_name == 'q':
        break

    print("\nHow about the number of sings:")
    sing_num = input('The number(Skip if N/A):')

    album = make_album(singer, album_name, sing_num)
    albums.append(album)
print(albums)
# Out:
# Enter 'q' at any time to quit
#
# Please enter the singer:
#
# Please enter the album:
#
# How about the number of sings:
#
# Please enter the singer:
#
# Please enter the album:
#
# How about the number of sings:
#
# Please enter the singer:
# [{'singer': 'wukai', 'album_name': 'shiyan'}, {'singer': 'wukai', 'album_name': 'shiyan', 'sing_num': '5'}]

# %% [markdown]
# # 8.4 传递列表

# %%
# greet_users.py
def greet_users(names):
    for _ in names:
        print(f"Hello, {_.title()} !")

usernames = ['hannah', 'ty', 'margot']
greet_users(usernames)
# Out:
# Hello, Hannah !
# Hello, Ty !
# Hello, Margot !

# %%
unprinted_designs = ['iphone case', 'robot pendant', 'dodecahedron']
completed_models = []

while unprinted_designs:
    current_design = unprinted_designs.pop()
    print(f"Printing model: {current_design}")
    completed_models.append(current_design)
print("\nThe following models have been printed:") 
for completed_model in completed_models: 
    print(completed_model)
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: iphone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# iphone case

# %%
def print_models(unprinted_designs, completed_models): 
    """ 
    模拟打印每个设计，直到没有未打印的设计为止 
    打印每个设计后,都将其移到列表completed_models中 
    """
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        print(f"Printing model: {current_design}")
        completed_models.append(current_design)

def show_completed_models(completed_models):
    """显示打印好的所有模型"""
    print("\nThe following models have been printed:")
    for completed_model in completed_models: 
        print(completed_model)

unprinted_designs = ['iphone case', 'robot pendant', 'dodecahedron'] 
completed_models = []
print_models(unprinted_designs, completed_models) 
show_completed_models(completed_models)
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: iphone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# iphone case

# %%
def print_models(unprinted_designs, completed_models): 
    """ 
    模拟打印每个设计，直到没有未打印的设计为止 
    打印每个设计后,都将其移到列表completed_models中 
    """
    while unprinted_designs:
        current_design = unprinted_designs.pop()
        print(f"Printing model: {current_design}")
        completed_models.append(current_design)

def show_completed_models(completed_models):
    """显示打印好的所有模型"""
    print("\nThe following models have been printed:")
    for completed_model in completed_models: 
        print(completed_model)

unprinted_designs = ['iphone case', 'robot pendant', 'dodecahedron'] 
completed_models = []
print_models(unprinted_designs[:], completed_models) 
show_completed_models(completed_models)
print(unprinted_designs)
print(completed_models)
# Out:
# Printing model: dodecahedron
# Printing model: robot pendant
# Printing model: iphone case
#
# The following models have been printed:
# dodecahedron
# robot pendant
# iphone case
# ['iphone case', 'robot pendant', 'dodecahedron']
# ['dodecahedron', 'robot pendant', 'iphone case']

# %%
# 8-9+10+11 magicians
magicians_names = [
    'Houdini',
    'David Copperfield',
    'Derren Brown',
    'Penn Jillette',
    'Teller',
    'Shin Lim',
    'Dynamo'
    ]

def show_magicians(names):
    for _ in names:
        print(_)

show_magicians(magicians_names)

#def make_great(names):
#    for _ in names:
#        great_names = f"the Great {_}"
#        magicians_names.append(great_names)
# 这么写把列表的长度不停地增加了，导致死循环了

def make_great(names):
    for i in range(len(names)):
        names[i] = f"the Great {names[i]}"
    print(f"\n{names}")

make_great(magicians_names[:])
show_magicians(magicians_names)
# Out:
# Houdini
# David Copperfield
# Derren Brown
# Penn Jillette
# Teller
# Shin Lim
# Dynamo
#
# ['the Great Houdini', 'the Great David Copperfield', 'the Great Derren Brown', 'the Great Penn Jillette', 'the Great Teller', 'the Great Shin Lim', 'the Great Dynamo']
# Houdini
# David Copperfield
# Derren Brown
# Penn Jillette
# Teller
# Shin Lim
# Dynamo

# %% [markdown]
# # 8.5 传递任意数量的实参

# %%
def make_pizza(*toppings):
    print("\nMaking a pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")

make_pizza('pepperoni')
make_pizza('mushroom', 'green peppers', 'extra cheese')
# Out:
# Making a pizza with the following toppings:
# - pepperoni
#
# Making a pizza with the following toppings:
# - mushroom
# - green peppers
# - extra cheese

# %%
def make_pizza(size, *toppings):
    print(f"\nMaking a {size} inch pizza with the following toppings:")
    for topping in toppings:
        print(f"- {topping}")

make_pizza(16, 'pepperoni')
make_pizza(15, 'mushroom', 'green peppers', 'extra cheese')
# Out:
# Making a 16 inch pizza with the following toppings:
# - pepperoni
#
# Making a 15 inch pizza with the following toppings:
# - mushroom
# - green peppers
# - extra cheese

# %%
# user_profile.py
def build_profile(first, last, **user_info):
    profile = {}
    profile['first_name'] = first
    profile['last_name'] = last
    for key, value in user_info.items():
        profile[key] = value
    return profile

user_profile = build_profile('albert', 'einstein', 
                            location='princeton', 
                            field='physics') 
print("profile = ",user_profile)
# Out:
# profile =  {'first_name': 'albert', 'last_name': 'einstein', 'location': 'princeton', 'field': 'physics'}

# %%
def example(a, *args, **kwargs):
    print("a =", a)
    print("args =", args)
    print("kwargs =", kwargs)

example(1, 2, 3, x=10, y=20)
# Out:
# a = 1
# args = (2, 3)
# kwargs = {'x': 10, 'y': 20}

# %%
# 8-12 sandwich
def sandwich(*ingredients):
    print("\nHere are your sandwich ingredients")
    for _ in ingredients:
        print(f"- {_}")

# 第一次调用：经典组合
sandwich('培根', '生菜', '番茄')

# 第二次调用：简单的芝士党
sandwich('切达芝士', '火腿')

# 第三次调用：豪华全家桶
sandwich('牛肉', '酸黄瓜', '洋葱', '蛋黄酱', '牛油果', '煎蛋')
# Out:
# Here are your sandwich ingredients
# - 培根
# - 生菜
# - 番茄
#
# Here are your sandwich ingredients
# - 切达芝士
# - 火腿
#
# Here are your sandwich ingredients
# - 牛肉
# - 酸黄瓜
# - 洋葱
# - 蛋黄酱
# - 牛油果
# - 煎蛋

# %%
# 8-13 user_introduction
def build_profile(first, last, **user_info):
    profile = {}
    profile['first_name'] = first
    profile['last_name'] = last
    for key, value in user_info.items():
        profile[key] = value
    return profile

user_profile = build_profile('wu', 'kaiyuan', 
                            location='Shiyan', 
                            field='Ensemble forecast',
                            exercise = 'street workout',
                            tall = 178) 
print("profile = ",user_profile)
# Out:
# profile =  {'first_name': 'wu', 'last_name': 'kaiyuan', 'location': 'Shiyan', 'field': 'Ensemble forecast', 'exercise': 'street workout', 'tall': 178}

# %%
# 8-14 cars
def make_car(brand, region, **others):
    cars = {}
    cars['brand'] = brand
    cars['region'] = region
    for key, value in others.items():
        cars[key] = value
    return cars

car = make_car('subaru', 'outback', color='blue', tow_package=True)
print("cars = ", car)
# Out:
# cars =  {'brand': 'subaru', 'region': 'outback', 'color': 'blue', 'tow_package': True}

# %%
# Out:
# Enter 'q' at any time to quit
#
# Please enter the singer:
#
# Please enter the album:
#
# Please enter the singer:
#
# Please enter the album:
#
# Please enter the singer:
# None

# %%
album_info = []


def make_album(singer, album):
    return {"singer": singer, "album": album}


def gather_album(album_dic):
    album_info.append(album_dic)
    return album_info


print("\nEnter 'q' at any time to quit")
while True:
    print("\nPlease enter the singer:")
    singer = input("Singer name:")
    if singer == "q":
        break

    print("\nPlease enter the album:")
    album = input("Album name:")
    if album == "q":
        break

    album_list = gather_album(make_album(singer, album))
print(album_list)
# Out:
# Enter 'q' at any time to quit
#
# Please enter the singer:
#
# Please enter the album:
#
# Please enter the singer:
#
# Please enter the album:
#
# Please enter the singer:
# [{'singer': '1', 'album': '2'}, {'singer': '3', 'album': '4'}]

# %%
album_info = []

def make_album(singer, album):
    """创建一个包含专辑信息的字典"""
    return {"singer": singer, "album": album}

print("\nEnter 'q' at any time to quit")

while True:
    print("\nPlease enter the details:")
    singer_input = input("Singer name: ").strip()
    if singer_input.lower() == 'q':
        break

    album_input = input("Album name: ").strip()
    if album_input.lower() == 'q':
        break

    # 1. 先生成字典
    album_dict = make_album(singer_input, album_input)
    
    # 2. 直接添加到列表中，逻辑更直观
    album_info.append(album_dict)

# 循环结束后，统一打印结果
print("\n--- 收集到的专辑列表 ---")
print(album_info)
# Out:
# Enter 'q' at any time to quit
#
# Please enter the details:
#
# Please enter the details:
#
# Please enter the details:
#
# --- 收集到的专辑列表 ---
# [{'singer': '1', 'album': '2'}, {'singer': '3', 'album': '4'}]

# %% [markdown]
# # 8.6 储存函数

# %% [markdown]
# 见`test`文件夹
